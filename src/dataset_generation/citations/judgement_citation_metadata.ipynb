# %%
import sys
import os
import json
from string import Template
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from citations.judgement_citation_metadata import get_metadata_for_case_id

ids = ['001-103259', '001-104367', '001-107033', '001-112101', '001-122881', '001-127410', '001-145277', '001-148683', '001-148927', '001-155895', '001-163926', '001-165078', '001-165265', '001-177319', '001-180706', '001-180802', '001-183961', '001-203533', '001-205509', '001-213717', '001-216748', '001-218132', '001-225324', '001-231739', '001-59159', '001-71314', '001-72364', '001-80616', '001-81182', '001-93373']
counter = 0

for case_id in ids:
    metadata = get_metadata_for_case_id(case_id)
    if metadata and metadata.get("isplaceholder", "False") != "True":
        print(json.dumps(metadata, indent=2))
        counter += 1

print(f"Not placeholders {counter}/{len(ids)}")
    
# metadata = get_metadata_for_case_id("001-103259")
# print(json.dumps(metadata, indent=2))
# Out:
# {
#   "typedescription": "15",
#   "application": "MS WORD",
#   "extractedappno": "34202/06;24360/04;30666/08;20652/92;26986/03;25691/04;74552/01;28495/06;28516/06;16999/04;10877/04;26258/07;26255/07;61821/00;10346/05;29372/02;29032/95;26682/95;5529/05;44079/98;13279/05;10519/03;35082/04;44306/98;22838/93;4916/07;25924/08;14599/09",
#   "conclusion": "No violation of Article 11 - Freedom of assembly and association (Article 11-1 - Freedom of peaceful assembly) read in the light of Article 10 - (Art. 10) Freedom of expression -{General} (Article 10-1 - Freedom of expression)",
#   "importance": "3",
#   "documentcollectionid": "CASELAW;JUDGMENTS;CHAMBER;ENG",
#   "appnoparts": "34202;06",
#   "docname": "CASE OF BERLADIR AND OTHERS v. RUSSIA",
#   "appno": "34202/06",
#   "originatingbody": "4",
#   "documentcollectionid2": "CASELAW;JUDGMENTS;CHAMBER;ENG",
#   "advopidentifier": null,
#   "itemid": "001-112101",
#   "isplaceholder": "False",
#   "doctype": "HEJUD",
# ...

# %%
import sys
import os
import json
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from citations.judgement_citation_metadata import search_hudoc
from citations.judgement_citation_metadata import get_metadata_for_case_id
from citations.judgement_citation_metadata import find_translations

#  Test find_translations
metadata = get_metadata_for_case_id("001-114082")

translations = find_translations(metadata)
print("\nTranslations output:\n" + json.dumps(translations, indent=2))
# Out:
# Duplicate language version found for ARM: {
# 	"id": 001-122480,
# 	"docname": CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA - [Armenian Translation] by the COE Human Rights Trust Fund,
# 	"date": 2012-10-19T00:00:00
# }
#
# Translations output:
# {
#   "orig_id": "001-114082",
#   "appno": "43370/04",
#   "eng": {
#     "id": "001-114082",
#     "docname": "CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA",
#     "date": "2012-10-19T00:00:00"
#   },
#   "fre": {
#     "id": "001-114222",
#     "docname": "AFFAIRE CATAN ET AUTRES c. R\u00c9PUBLIQUE DE MOLDOVA ET RUSSIE",
#     "date": "2012-10-19T00:00:00"
#   },
#   "ALB": {
#     "id": "001-127351",
#     "docname": "CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA - [Albanian Translation] by the COE Human Rights Trust Fund",
#     "date": "2012-10-19T00:00:00"
#   },
#   "ARM": {
#     "id": "001-119530",
# ...

# %%
import sys
import os
import json
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from citations.judgement_citation_metadata import multilingual_citations

multilingual_citations = multilingual_citations("https://hudoc.echr.coe.int/eng?i=001-114082", 'ron')
print( json.dumps(multilingual_citations, indent=2, ensure_ascii=False))
# Out:
# Duplicate language version found for ARM: {
# 	"id": 001-122480,
# 	"docname": CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA - [Armenian Translation] by the COE Human Rights Trust Fund,
# 	"date": 2012-10-19T00:00:00
# }
# {
#   "orig_id": "001-114082",
#   "appno": "43370/04",
#   "lang_versions": {
#     "eng": {
#       "id": "001-114082",
#       "docname": "CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA",
#       "date": "2012-10-19T00:00:00"
#     },
#     "fre": {
#       "id": "001-114222",
#       "docname": "AFFAIRE CATAN ET AUTRES c. RÉPUBLIQUE DE MOLDOVA ET RUSSIE",
#       "date": "2012-10-19T00:00:00"
#     },
#     "ron": {
#       "id": "001-124596",
#       "docname": "CASE OF CATAN AND OTHERS v. THE REPUBLIC OF MOLDOVA AND RUSSIA - [Romanian Translation] by the P.A. \"Lawyers for Human Rights\"",
#       "date": "2012-10-19T00:00:00"
#     }
#   }
# }
